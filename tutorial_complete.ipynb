# %% [markdown]
# # From laptop to NERSC: bringing your scientific notebook with you
#
# Package the software for an ATLAS Open Data analysis, then run it through NERSC JupyterHub using a container-backed kernel.
#
# **By the end, you’ll be able to:**
#
# - Create and build a container image.
# - Configure and select a Jupyter kernel that uses that container at NERSC.
#
# **Note:** All demonstrations take place on Perlmutter. No container software is needed on your laptop.
#
# ## Table of Contents
#
# - [1. Introduction](#1---Introduction)
# - [2. ATLAS - Find the Z Boson analysis](#2---ATLAS---Find-the-Z-Boson-analysis)
# - [3. Containers](#3---Containers)
# - [4. Containers on NERSC JupyterHub](#4---Containers-on-NERSC-JupyterHub)
# - [5. Running the Analysis](#5---Running-the-Analysis)
# - [6. Summary and Further Exploration](#6---Summary-and-Further-Exploration)

# %% [markdown]
# <img src="images/tutorial-workflow.svg" alt="All steps take place at NERSC: start with the ATLAS notebook and software requirements (Section 2), package the software (Section 3), tell Jupyter to use it (Section 4), and run the analysis (Section 5)." width="1120" style="max-width: 100%; height: auto;">
#
# We keep the notebook and analysis code, package the required software, and configure Jupyter to run Python inside that container.

# %% [markdown]
# ## 1 - Introduction

# %% [markdown]
# ### Why move your analysis to NERSC?
#
# Your notebook may work well on your laptop, but you may want to:
#
# - **Work where the data reside:** access datasets at NERSC, including those shared by your collaboration.
# - **Use more memory:** run an analysis whose working data exceed your laptop’s RAM.
# - **Access more computing capacity:** process many files or run multiple analyses in parallel.
# - **Use specialized hardware:** access GPUs unavailable on your laptop.
#
# ### The notebook is only part of the analysis
#
# A notebook needs Python, packages, and their supporting libraries. Copying the notebook doesn’t recreate that environment: missing packages or incompatible versions can stop a working analysis.
#
# We’ll package the environment in a container and connect it to Jupyter at NERSC.

# %% [markdown]
# ## 2 - ATLAS - Find the Z Boson analysis

# %% [markdown]
# ATLAS is a particle physics experiment at CERN’s Large Hadron Collider. Proton collisions produce particles whose energies and momenta are measured by the detector to study fundamental physics.
#
# We’ll use [ATLAS Open Data](https://opendata.atlas.cern/) to reconstruct the Z boson mass from the two muons produced in its decay.

# %% [markdown]
# <img src="images/Zee_feynman.png" alt="Feynman diagram showing a Z boson decaying into a positron and an electron." width="600">
#
# *The diagram illustrates a Z boson decaying into an electron–positron pair. Our analysis uses the corresponding decay into a muon–antimuon pair.*
#
# Figure: [ATLAS Open Data, Find the Z notebook collection](https://github.com/atlas-outreach-data-tools/notebooks-collection-opendata/blob/8b7ee0050ae0e34d072fb017da662be0c32ab97c/13-TeV-examples/uproot_python/images/feynman_diagrams/Zee_feynman.png), reproduced unchanged. See [license and provenance](UPSTREAM.md).

# %% [markdown]
# ### What does the analysis do?
#
# 1. Read the measured energies and momenta of two muons.
# 2. Calculate their **invariant mass**—the mass reconstructed from their combined energy and momentum.
# 3. Plot the distribution and look for the Z boson peak.
#
# The code is adapted from the [ATLAS Open Data *Find the Z* notebook](https://github.com/atlas-outreach-data-tools/notebooks-collection-opendata/blob/8b7ee0050ae0e34d072fb017da662be0c32ab97c/13-TeV-examples/uproot_python/Find_the_Z.ipynb) into [Python functions](utils/find_the_z.py) for this tutorial. Converting a notebook to a script is not required to use containers.

# %% [markdown]
# ## 3 - Containers

# %% [markdown]
# ### What is a container?
#
# A **container** runs an application in an isolated process environment. Our analysis uses the container's Python, packages, and system libraries while sharing the host's Linux kernel, rather than booting its own operating system.
#
# A **container image** is the packaged software environment we build and store. Starting a process from that image creates a running container. In this tutorial, the image supplies the dependencies; the analysis code stays in our repository, made accessible inside the container through a mount.
#
# Container tooling such as **podman-hpc** starts and manages the container; the host's Linux kernel provides the isolation. This operating-system kernel is different from the **Jupyter kernel** that runs our Python code in Section 4.
#
# <img src="images/container-environment.svg" alt="An isolated container runs analysis code from the mounted repository using Python, packages, and system libraries supplied by the image. Beneath it are podman-hpc, the shared host Linux kernel, and host hardware." width="720">
#
# *The image supplies the software environment; the running container shares the host's Linux kernel. [More about containers (Docker)](https://docs.docker.com/get-started/docker-concepts/the-basics/what-is-a-container/).*

# %% [markdown]
# ### Why use a container?
#
# A Conda environment created from `environment.yml` is enough for many workflows. A container packages a broader software environment:
#
# - **Portability:** carry it between compatible computing systems.
# - **Reproducibility:** reuse a specific image with the same software versions.
# - **Environment control:** include system libraries and tools.
# - **Reuse:** start from images built by scientific projects.
#
# <details>
# <summary>Rebuilding and compatibility</summary>
#
# An image preserves its software, but rebuilding can change unpinned dependencies or the base image. Compatible hardware and host drivers still matter.
#
# </details>

# %% [markdown]
# ### From an environment definition to an image
#
# **The YAML describes what to install; the image contains the environment we build.**
#
# - [`environment.yml`](environment.yml): the required packages.
# - [`Containerfile`](Containerfile): the build recipe, using Dockerfile syntax.

# %% [markdown]
# #### The package requirements
#
# Our [`environment.yml`](environment.yml) includes the analysis packages, HTTP data-access libraries, and `ipykernel` for Jupyter:
#
# ```yaml
# name: atlas-notebook-find-z
# channels:
#   - conda-forge
#   - nodefaults
# dependencies:
#   - python=3.11.16
#   - aiohttp=3.14.3
#   - atlasopenmagic=1.10.1
#   - awkward=2.13.0
#   - ipykernel=6.31.0
#   - matplotlib-base=3.11.1
#   - numpy=2.4.6
#   - pandas=2.3.3
#   - requests=2.34.2
#   - uproot=5.7.6
#   - vector=1.8.1
# ```
#
# Packages come from **conda-forge**. `ipykernel` runs Python for Jupyter; `requests` and `aiohttp` support remote data access. NERSC supplies the Jupyter server.

# %% [markdown]
# #### The build instructions
#
# Our [`Containerfile`](Containerfile):
#
# ```dockerfile
# FROM docker.io/mambaorg/micromamba:2.9.0
#
# COPY --chmod=644 environment.yml /opt/environment.yml
# RUN micromamba install --yes --name base --file /opt/environment.yml && \
#     micromamba clean --all --yes
#
# WORKDIR /tmp
# CMD ["python"]
# ```
#
# - **`FROM`:** start from an image containing Micromamba.
# - **`COPY`:** add the environment file and make it readable during installation.
# - **`RUN`:** install the packages and clean up download caches.
#
# The image contains the software; notebooks, analysis scripts, and data stay outside it.
#
# <details>
# <summary>Environment and runtime details</summary>
#
# `--name base` installs into the image’s base environment, whose Python is `/opt/conda/bin/python`. The image inherits the non-root `mambauser` (UID/GID `57439`); `--chmod=644` makes the copied YAML readable even with restrictive checkout permissions.
#
# Keep the base image’s entrypoint: it activates the environment. The image starts in `/tmp`; Section 4 mounts your files and selects the analysis directory after startup.
#
# See the [Micromamba container guide](https://micromamba-docker.readthedocs.io/en/latest/quick_start.html).
#
# </details>

# %% [markdown]
# ### Build our analysis image
#
# **Podman-HPC** builds and runs containers at NERSC.
#
# **Where to run:** use a **Perlmutter login-node terminal**, or **NERSC Python on a login node**. Do not run these Bash commands inside the ATLAS container kernel. In a terminal, omit `%%bash`; run from the repository directory.

# %%
# %%bash
# podman-hpc build --file Containerfile --tag localhost/atlas-notebook-find-z:v1 .
# Out:
# STEP 1/6: FROM docker.io/mambaorg/micromamba:2.9.0
# Trying to pull docker.io/mambaorg/micromamba:2.9.0...
# Getting image source signatures
# Copying blob sha256:1fef741ab06247a06d237ff4f0ac85a2d1335d7b8b27366682c539aa73999e81
# Copying blob sha256:2adeaf42ef931fa8dccb5ce2b6dabed10e8e64f2ef4e104a0fbb9c07d86887c4
# Copying blob sha256:a28f3a339ecc3a9267bffb8bdac8fd41ddef81e7d7cd7731f3b513e67d7a0b06
# Copying blob sha256:6310eb16bf4251731feab01e8f633bf5e2d75a657ccad97f420b1f83cce457be
# Copying blob sha256:ef4d979bcd605dc8eff7bd3891f4779d9828789d0e7fdaff3d1137a2ab9b97d7
# Copying blob sha256:7babf3ae8ba7e88c834ff2797b314f31a4206cf8b63f4486db0af0b0fe014b77
# Copying blob sha256:4f4fb700ef54461cfa02571ae0db9a0dc1e0cdb5577484a6d75e68dc38e8acc1
# Copying blob sha256:469d8a52ceef495177c5ce8eaf7edb41b6251528f2d8dab655ad8dac6f188b9b
# Copying blob sha256:d9233fe049ce32df59dde18905d0cf3a94716e9501219ee80eb52b1f95fbd78e
# Copying blob sha256:396876d99c9e9678356e0e870909a55fd93922625e7def3d6d9221a141628dff
# Copying blob sha256:0e88b77f1be82e825ed9b401b2da7c743dd26498199995b7988086a62de2db6f
# Copying config sha256:b8a24974acbc7a0cd2eb4dce837e76bc8fa7ec87f34f996158c8d0e2d37d28bd
# Writing manifest to image destination
# STEP 2/6: ENV "PODMANHPC_MODULES_DIR"="/etc/podman_hpc/modules.d"
# --> 7be76e560958
# STEP 3/6: COPY --chmod=644 environment.yml /opt/environment.yml
# --> bfff543a865a
# STEP 4/6: RUN micromamba install --yes --name base --file /opt/environment.yml &&     micromamba clean --all --yes
# Fetch Shard Index for conda-forge/linux-64                                                      ⧖ Starting
# Fetch Shard Index for conda-forge/linux-64                                                ✔ Done (0.2 sec)
# Fetch Shard Index for conda-forge/noarch                                                        ⧖ Starting
# Fetch Shard Index for conda-forge/noarch                                                  ✔ Done (0.2 sec)
# Fetching and Parsing Packages' Shards                                                           ⧖ Starting
# Fetching and Parsing Packages' Shards                                                    ✔ Done (14.7 sec)
#
# Resolving Environment                                                                           ⧖ Starting
# Resolving Environment                                                                     ✔ Done (0.5 sec)
#
# Transaction
#
#   Prefix: /opt/conda
#
#   Updating specs:
#
#    - python=3.11.16
#    - aiohttp=3.14.3
#    - atlasopenmagic=1.10.1
#    - awkward=2.13.0
#    - ipykernel=6.31.0
#    - matplotlib-base=3.11.1
#    - numpy=2.4.6
#    - pandas=2.3.3
#    - requests=2.34.2
#    - uproot=5.7.6
#    - vector=1.8.1
#    - pip
#
#
#   Package                           Version  Build                 Channel          Size
# ──────────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ──────────────────────────────────────────────────────────────────────────────────────────
#
#   + _openmp_mutex                       4.5  20_gnu                conda-forge      29kB
#   + _x86_64-microarch-level               3  3_x86_64_v3           conda-forge      10kB
#   + aiohappyeyeballs                  2.7.1  pyhd8ed1ab_0          conda-forge      25kB
#   + aiohttp                          3.14.3  py311h55b9665_0       conda-forge       1MB
#   + aiosignal                         1.4.0  pyhd8ed1ab_0          conda-forge      14kB
#   + asttokens                         3.0.2  pyhd8ed1ab_0          conda-forge      35kB
#   + atlasopenmagic                   1.10.1  pyhc364b38_0          conda-forge      47kB
#   + attrs                            26.1.0  pyhcf101f3_0          conda-forge      65kB
#   + awkward                          2.13.0  pyhcf101f3_0          conda-forge     542kB
#   + awkward-cpp                          56  py311h2bf5405_2       conda-forge     674kB
#   + backports.zstd                    1.7.0  py311h6f959d0_1       conda-forge     248kB
#   + brotli                            1.2.0  h505cf86_4            conda-forge      21kB
#   + brotli-bin                        1.2.0  h9908984_4            conda-forge      22kB
#   + brotli-python                     1.2.0  py311heb3be6f_4       conda-forge     367kB
#   + bzip2                             1.0.8  hda65f42_10           conda-forge     258kB
#   + ca-certificates               2026.7.22  hbd8a1cb_0            conda-forge     132kB
#   + cairo                            1.18.4  h3c89d7e_3            conda-forge     991kB
#   + certifi                       2026.7.22  pyhd8ed1ab_0          conda-forge     137kB
#   + charset-normalizer                3.5.1  pyhd8ed1ab_0          conda-forge      64kB
#   + comm                              0.2.3  pyhe01879c_0          conda-forge      15kB
#   + contourpy                         1.3.3  py311h724c32c_4       conda-forge     321kB
#   + cramjam                          2.11.0  py311hc665cac_2       conda-forge       2MB
#   + cycler                           0.12.1  pyhcf101f3_2          conda-forge      15kB
#   + debugpy                          1.8.21  py311hdfc3925_2       conda-forge       3MB
#   + executing                         2.2.1  pyhd8ed1ab_0          conda-forge      31kB
#   + font-ttf-dejavu-sans-mono          2.37  hab24e00_0            conda-forge     397kB
#   + font-ttf-inconsolata              3.000  h77eed37_0            conda-forge      97kB
#   + font-ttf-source-code-pro          2.038  h77eed37_0            conda-forge     701kB
#   + font-ttf-ubuntu                    0.83  h77eed37_3            conda-forge       2MB
#   + fontconfig                       2.18.3  h4db4eae_1            conda-forge     296kB
#   + fonts-conda-ecosystem                 1  0                     conda-forge       4kB
#   + fonts-conda-forge                     1  hc364b38_1            conda-forge       4kB
#   + fonttools                        4.65.0  py311h92159aa_0       conda-forge       3MB
#   + freetype                         2.14.3  ha770c72_2            conda-forge     175kB
#   + fribidi                          1.0.16  h7cc23a3_2            conda-forge      62kB
#   + frozenlist                        1.8.0  py311h52bc045_0       conda-forge      54kB
#   + fsspec                         2026.7.0  pyhd8ed1ab_0          conda-forge     152kB
#   + graphite2                        1.3.15  h54a6638_1            conda-forge     103kB
#   + h2                                4.4.1  pyhcf101f3_0          conda-forge     101kB
#   + hpack                             4.2.0  pyhd8ed1ab_0          conda-forge      33kB
#   + hyperframe                        6.1.0  pyhd8ed1ab_0          conda-forge      17kB
#   + icu                                78.3  py310h44b86e0_2       conda-forge      14MB
#   + idna                               3.19  pyhcf101f3_0          conda-forge     177kB
#   + importlib-metadata                9.0.1  pyhcf101f3_0          conda-forge      35kB
#   + ipykernel                        6.31.0  pyha191276_0          conda-forge     130kB
#   + ipython                          9.17.1  pyh53cf698_0          conda-forge     731kB
#   + ipython_pygments_lexers           1.1.1  pyhd8ed1ab_0          conda-forge      14kB
#   + jedi                             0.20.0  pyhcf101f3_0          conda-forge       3MB
#   + jupyter_client                   8.10.0  pyhcf101f3_0          conda-forge     119kB
#   + jupyter_core                      5.9.1  pyhc90fa1f_0          conda-forge      66kB
#   + keyutils                          1.6.3  h7cc23a3_1            conda-forge     135kB
#   + kiwisolver                        1.5.1  py311h4c6fd42_1       conda-forge      77kB
#   + krb5                             1.22.2  hbc21106_2            conda-forge       1MB
#   + lcms2                            2.19.1  h9073bf1_3            conda-forge     254kB
#   + ld_impl_linux-64                 2.46.1  default_hbd61a6d_102  conda-forge     745kB
#   + lerc                              4.2.0  hdb68285_0            conda-forge     271kB
#   + libblas                          3.11.0  11_h4a7cf45_openblas  conda-forge      18kB
#   + libbrotlicommon                   1.2.0  h39a168f_4            conda-forge      81kB
#   + libbrotlidec                      1.2.0  ha411449_4            conda-forge      35kB
#   + libbrotlienc                      1.2.0  h018ffa1_4            conda-forge     298kB
#   + libcblas                         3.11.0  11_h0358290_openblas  conda-forge      18kB
#   + libdeflate                         1.25  hd45a770_1            conda-forge      74kB
#   + libedit                    3.1.20250104  pl5321h373387f_1      conda-forge     135kB
#   + libexpat                          2.8.1  hecca717_1            conda-forge      78kB
#   + libffi                            3.7.0  h81df57d_1            conda-forge      68kB
#   + libfreetype                      2.14.3  ha770c72_2            conda-forge       8kB
#   + libfreetype6                     2.14.3  h5e6c136_2            conda-forge     388kB
#   + libgcc                           16.2.0  ha9f2e26_5            conda-forge       1MB
#   + libgcc-ng                        16.2.0  h69a702a_5            conda-forge      29kB
#   + libgfortran                      16.2.0  h69a702a_5            conda-forge      29kB
#   + libgfortran5                     16.2.0  h6b99dfc_5            conda-forge       3MB
#   + libglib                          2.90.0  h569388d_0            conda-forge       5MB
#   + libgomp                          16.2.0  he0feb66_5            conda-forge     642kB
#   + libharfbuzz                      14.4.0  h23af247_1            conda-forge       1MB
#   + libiconv                           1.18  h0cb94f2_3            conda-forge     789kB
#   + libjpeg-turbo                     3.2.0  hb03c661_1            conda-forge     650kB
#   + liblapack                        3.11.0  11_h47877c9_openblas  conda-forge      18kB
#   + liblzma                           5.8.3  hb03c661_1            conda-forge     113kB
#   + libnsl                            2.0.1  hb9d3cd8_1            conda-forge      34kB
#   + libopenblas                      0.3.34  pthreads_hf13c14d_2   conda-forge       7MB
#   + libpng                           1.6.58  h922cc85_1            conda-forge     317kB
#   + libpython                       3.11.16  h0c77377_2_cpython    conda-forge       8MB
#   + libraqm                          0.11.0  h6406941_0            conda-forge      34kB
#   + libsodium                        1.0.22  hebe6cf0_3            conda-forge     271kB
#   + libsqlite                        3.53.4  h13e7031_1            conda-forge     974kB
#   + libstdcxx                        16.2.0  h934c35e_5            conda-forge       7MB
#   + libstdcxx-ng                     16.2.0  hdf11a46_5            conda-forge      29kB
#   + libtiff                           4.7.2  hcc2c06a_1            conda-forge     460kB
#   + libuuid                          2.42.3  hcfc3c73_0            conda-forge      40kB
#   + libwebp-base                      1.6.0  hd42ef1d_1            conda-forge     428kB
#   + libxcb                           1.17.0  hb83e432_2            conda-forge     395kB
#   + libxcrypt                        4.4.38  h280c20c_0            conda-forge     102kB
#   + libzlib                           1.3.2  h25fd6f3_3            conda-forge      64kB
#   + matplotlib-base                  3.11.1  py311he401cf6_2       conda-forge       9MB
#   + matplotlib-inline                 0.2.2  pyhd8ed1ab_0          conda-forge      16kB
#   + multidict                         6.7.1  py311h3778330_0       conda-forge     101kB
#   + munkres                           1.1.4  pyhd8ed1ab_1          conda-forge      16kB
#   + ncurses                             6.6  hdb14827_1            conda-forge     911kB
#   + nest-asyncio                      1.6.0  pyhd8ed1ab_1          conda-forge      12kB
#   + numpy                             2.4.6  py311h2e04523_0       conda-forge       9MB
#   + openjpeg                          2.5.4  heb1ab33_2            conda-forge     391kB
#   + openssl                           3.6.4  h781a0a9_0            conda-forge       3MB
#   + packaging                          26.3  pyhc364b38_0          conda-forge     116kB
#   + pandas                            2.3.3  py311hed34c8f_2       conda-forge      15MB
#   + parso                             0.8.7  pyhcf101f3_0          conda-forge      82kB
#   + pcre2                             10.47  h8b3dc9c_1            conda-forge       1MB
#   + pexpect                           4.9.0  pyhd8ed1ab_1          conda-forge      54kB
#   + pillow                           12.3.0  py311hf303fd3_4       conda-forge       1MB
#   + pip                              26.2.1  pyh8b19718_0          conda-forge       1MB
#   + pixman                           0.46.4  h54a6638_3            conda-forge     377kB
#   + platformdirs                     4.11.8  pyh5ded981_0          conda-forge      28kB
#   + prompt-toolkit                   3.0.53  pyha770c72_0          conda-forge     276kB
#   + propcache                         0.5.2  py311h3778330_0       conda-forge      51kB
#   + psutil                            7.2.2  py311h194be0f_2       conda-forge     232kB
#   + pthread-stubs                       0.4  h7cc23a3_1004         conda-forge      10kB
#   + ptyprocess                        0.7.0  pyhd8ed1ab_1          conda-forge      19kB
#   + pure_eval                         0.2.4  pyhd8ed1ab_0          conda-forge      18kB
#   + pygments                         2.21.0  pyhcf101f3_0          conda-forge     959kB
#   + pyparsing                         3.3.2  pyhcf101f3_0          conda-forge     111kB
#   + pysocks                           1.7.1  pyha55dd90_7          conda-forge      21kB
#   + python                          3.11.16  h5f976f7_2_cpython    conda-forge      23MB
#   + python-dateutil             2.9.0.post0  pyhe01879c_2          conda-forge     233kB
#   + python-tzdata                    2026.3  pyhd8ed1ab_0          conda-forge     147kB
#   + python-xxhash                     3.7.0  py311h6cc6551_1       conda-forge      25kB
#   + python_abi                         3.11  9_cp311               conda-forge       7kB
#   + pytz                       2026.3.post1  pyhcf101f3_0          conda-forge     201kB
#   + pyyaml                            6.0.3  py311h3778330_1       conda-forge     206kB
#   + pyzmq                            27.2.0  py311hcbe55da_1       conda-forge     396kB
#   + qhull                            2020.2  h434a139_5            conda-forge     553kB
#   + readline                            8.3  hd6e31c0_1            conda-forge     349kB
#   + requests                         2.34.2  pyhcf101f3_0          conda-forge      69kB
#   + setuptools                       84.0.0  pyh332efcf_0          conda-forge     524kB
#   + six                              1.17.0  pyhe01879c_1          conda-forge      18kB
#   + stack_data                        0.6.3  pyhd8ed1ab_1          conda-forge      27kB
#   + tk                               8.6.13  noxft_h1df4ec4_4      conda-forge       4MB
#   + tornado                           6.5.8  py311h0d48ccd_2       conda-forge     889kB
#   + tqdm                             4.70.1  pyhfa0c392_0          conda-forge      96kB
#   + traitlets                        5.16.1  pyhcf101f3_0          conda-forge     117kB
#   + typing_extensions                4.16.0  pyhcf101f3_0          conda-forge      53kB
#   + tzdata                            2026c  h151e31d_0            conda-forge     119kB
#   + unicodedata2                     17.0.1  py311h0d48ccd_1       conda-forge     413kB
#   + uproot                            5.7.6  pyhc364b38_0          conda-forge     287kB
#   + urllib3                           2.7.0  pyhd8ed1ab_0          conda-forge     104kB
#   + vector                            1.8.1  pyhc364b38_0          conda-forge      98kB
#   + wcwidth                           0.8.3  pyhcf101f3_0          conda-forge     146kB
#   + wheel                            0.48.0  pyhd8ed1ab_0          conda-forge      35kB
#   + xorg-libice                       1.1.2  h280c20c_0            conda-forge      63kB
#   + xorg-libsm                        1.2.6  h0d788c3_1            conda-forge      31kB
#   + xorg-libx11                      1.8.13  he1eb515_1            conda-forge     840kB
#   + xorg-libxau                      1.0.12  h7cc23a3_2            conda-forge      19kB
#   + xorg-libxdmcp                     1.1.5  hb03c661_2            conda-forge      21kB
#   + xorg-libxext                      1.3.7  h7cc23a3_1            conda-forge      53kB
#   + xorg-libxrender                  0.9.12  hb03c661_1            conda-forge      35kB
#   + xxhash                            0.8.3  hec8ed23_1            conda-forge     109kB
#   + yaml                              0.2.5  hebe6cf0_3            conda-forge      85kB
#   + yarl                             1.24.5  py311h3778330_0       conda-forge     173kB
#   + zeromq                            4.3.5  h901266b_12           conda-forge     322kB
#   + zipp                              4.1.0  pyhcf101f3_0          conda-forge      24kB
#   + zlib-ng                           2.3.3  hce19668_1            conda-forge     124kB
#   + zstd                              1.5.7  hb78ec9c_7            conda-forge     601kB
#
#   Summary:
#
#   Install: 160 packages
#
#   Total download: 154MB
#
# ──────────────────────────────────────────────────────────────────────────────────────────
# warning  libmamba Security Warning: This transaction includes executing package scripts (pre/post-link/unlink) if present. These scripts can contain arbitrary code. Please ensure you trust the package sources.
# Transaction starting
# Linking python_abi-3.11-9_cp311
# Linking tzdata-2026c-h151e31d_0
# Linking _x86_64-microarch-level-3-3_x86_64_v3
# Linking font-ttf-dejavu-sans-mono-2.37-hab24e00_0
# Linking font-ttf-inconsolata-3.000-h77eed37_0
# Linking font-ttf-source-code-pro-2.038-h77eed37_0
# Linking font-ttf-ubuntu-0.83-h77eed37_3
# Linking ca-certificates-2026.7.22-hbd8a1cb_0
# Linking fonts-conda-forge-1-hc364b38_1
# Linking fonts-conda-ecosystem-1-0
# Linking libzlib-1.3.2-h25fd6f3_3
# Linking libgomp-16.2.0-he0feb66_5
# Linking zstd-1.5.7-hb78ec9c_7
# Linking _openmp_mutex-4.5-20_gnu
# Linking ld_impl_linux-64-2.46.1-default_hbd61a6d_102
# Linking libgcc-16.2.0-ha9f2e26_5
# Linking xorg-libxau-1.0.12-h7cc23a3_2
# Linking xorg-libice-1.1.2-h280c20c_0
# Linking yaml-0.2.5-hebe6cf0_3
# Linking keyutils-1.6.3-h7cc23a3_1
# Linking libdeflate-1.25-hd45a770_1
# Linking libsodium-1.0.22-hebe6cf0_3
# Linking libiconv-1.18-h0cb94f2_3
# Linking pthread-stubs-0.4-h7cc23a3_1004
# Linking xorg-libxdmcp-1.1.5-hb03c661_2
# Linking libgfortran5-16.2.0-h6b99dfc_5
# Linking libwebp-base-1.6.0-hd42ef1d_1
# Linking libjpeg-turbo-3.2.0-hb03c661_1
# Linking libbrotlicommon-1.2.0-h39a168f_4
# Linking bzip2-1.0.8-hda65f42_10
# Linking libnsl-2.0.1-hb9d3cd8_1
# Linking libexpat-2.8.1-hecca717_1
# Linking openssl-3.6.4-h781a0a9_0
# Linking libffi-3.7.0-h81df57d_1
# Linking liblzma-5.8.3-hb03c661_1
# Linking ncurses-6.6-hdb14827_1
# Linking tk-8.6.13-noxft_h1df4ec4_4
# Linking libgcc-ng-16.2.0-h69a702a_5
# Linking xxhash-0.8.3-hec8ed23_1
# Linking libpng-1.6.58-h922cc85_1
# Linking fribidi-1.0.16-h7cc23a3_2
# Linking libstdcxx-16.2.0-h934c35e_5
# Linking libuuid-2.42.3-hcfc3c73_0
# Linking libxcrypt-4.4.38-h280c20c_0
# Linking libxcb-1.17.0-hb83e432_2
# Linking libgfortran-16.2.0-h69a702a_5
# Linking libbrotlidec-1.2.0-ha411449_4
# Linking libbrotlienc-1.2.0-h018ffa1_4
# Linking pcre2-10.47-h8b3dc9c_1
# Linking libedit-3.1.20250104-pl5321h373387f_1
# Linking readline-8.3-hd6e31c0_1
# Linking libfreetype6-2.14.3-h5e6c136_2
# Linking graphite2-1.3.15-h54a6638_1
# Linking zlib-ng-2.3.3-hce19668_1
# Linking icu-78.3-py310h44b86e0_2
# Linking pixman-0.46.4-h54a6638_3
# Linking lerc-4.2.0-hdb68285_0
# Linking libstdcxx-ng-16.2.0-hdf11a46_5
# Linking libpython-3.11.16-h0c77377_2_cpython
# Linking xorg-libsm-1.2.6-h0d788c3_1
# Linking xorg-libx11-1.8.13-he1eb515_1
# Linking libopenblas-0.3.34-pthreads_hf13c14d_2
# Linking brotli-bin-1.2.0-h9908984_4
# Linking libglib-2.90.0-h569388d_0
# Linking krb5-1.22.2-hbc21106_2
# Linking libfreetype-2.14.3-ha770c72_2
# Linking libsqlite-3.53.4-h13e7031_1
# Linking libtiff-4.7.2-hcc2c06a_1
# Linking qhull-2020.2-h434a139_5
# Linking xorg-libxrender-0.9.12-hb03c661_1
# Linking xorg-libxext-1.3.7-h7cc23a3_1
# Linking libblas-3.11.0-11_h4a7cf45_openblas
# Linking brotli-1.2.0-h505cf86_4
# Linking zeromq-4.3.5-h901266b_12
# Linking fontconfig-2.18.3-h4db4eae_1
# Linking freetype-2.14.3-ha770c72_2
# Linking python-3.11.16-h5f976f7_2_cpython
# Linking openjpeg-2.5.4-heb1ab33_2
# Linking lcms2-2.19.1-h9073bf1_3
# Linking libcblas-3.11.0-11_h0358290_openblas
# Linking liblapack-3.11.0-11_h47877c9_openblas
# Linking cairo-1.18.4-h3c89d7e_3
# Linking backports.zstd-1.7.0-py311h6f959d0_1
# Linking brotli-python-1.2.0-py311heb3be6f_4
# Linking unicodedata2-17.0.1-py311h0d48ccd_1
# Linking propcache-0.5.2-py311h3778330_0
# Linking multidict-6.7.1-py311h3778330_0
# Linking kiwisolver-1.5.1-py311h4c6fd42_1
# Linking debugpy-1.8.21-py311hdfc3925_2
# Linking tornado-6.5.8-py311h0d48ccd_2
# Linking psutil-7.2.2-py311h194be0f_2
# Linking pyzmq-27.2.0-py311hcbe55da_1
# Linking cramjam-2.11.0-py311hc665cac_2
# Linking python-xxhash-3.7.0-py311h6cc6551_1
# Linking pyyaml-6.0.3-py311h3778330_1
# Linking frozenlist-1.8.0-py311h52bc045_0
# Linking pillow-12.3.0-py311hf303fd3_4
# Linking numpy-2.4.6-py311h2e04523_0
# Linking libharfbuzz-14.4.0-h23af247_1
# Linking contourpy-1.3.3-py311h724c32c_4
# Linking awkward-cpp-56-py311h2bf5405_2
# Linking libraqm-0.11.0-h6406941_0
# Linking platformdirs-4.11.8-pyh5ded981_0
# Linking ptyprocess-0.7.0-pyhd8ed1ab_1
# Linking wcwidth-0.8.3-pyhcf101f3_0
# Linking six-1.17.0-pyhe01879c_1
# Linking pysocks-1.7.1-pyha55dd90_7
# Linking hpack-4.2.0-pyhd8ed1ab_0
# Linking hyperframe-6.1.0-pyhd8ed1ab_0
# Linking parso-0.8.7-pyhcf101f3_0
# Linking pure_eval-0.2.4-pyhd8ed1ab_0
# Linking executing-2.2.1-pyhd8ed1ab_0
# Linking asttokens-3.0.2-pyhd8ed1ab_0
# Linking munkres-1.1.4-pyhd8ed1ab_1
# Linking aiohappyeyeballs-2.7.1-pyhd8ed1ab_0
# Linking attrs-26.1.0-pyhcf101f3_0
# Linking cycler-0.12.1-pyhcf101f3_2
# Linking pyparsing-3.3.2-pyhcf101f3_0
# Linking python-tzdata-2026.3-pyhd8ed1ab_0
# Linking pytz-2026.3.post1-pyhcf101f3_0
# Linking setuptools-84.0.0-pyh332efcf_0
# Linking pygments-2.21.0-pyhcf101f3_0
# Linking zipp-4.1.0-pyhcf101f3_0
# Linking comm-0.2.3-pyhe01879c_0
# Linking nest-asyncio-1.6.0-pyhd8ed1ab_1
# Linking traitlets-5.16.1-pyhcf101f3_0
# Linking charset-normalizer-3.5.1-pyhd8ed1ab_0
# Linking idna-3.19-pyhcf101f3_0
# Linking certifi-2026.7.22-pyhd8ed1ab_0
# Linking fsspec-2026.7.0-pyhd8ed1ab_0
# Linking tqdm-4.70.1-pyhfa0c392_0
# Linking packaging-26.3-pyhc364b38_0
# Linking typing_extensions-4.16.0-pyhcf101f3_0
# Linking pexpect-4.9.0-pyhd8ed1ab_1
# Linking prompt-toolkit-3.0.53-pyha770c72_0
# Linking python-dateutil-2.9.0.post0-pyhe01879c_2
# Linking h2-4.4.1-pyhcf101f3_0
# Linking jedi-0.20.0-pyhcf101f3_0
# Linking stack_data-0.6.3-pyhd8ed1ab_1
# Linking ipython_pygments_lexers-1.1.1-pyhd8ed1ab_0
# Linking importlib-metadata-9.0.1-pyhcf101f3_0
# Linking matplotlib-inline-0.2.2-pyhd8ed1ab_0
# Linking jupyter_core-5.9.1-pyhc90fa1f_0
# Linking wheel-0.48.0-pyhd8ed1ab_0
# Linking vector-1.8.1-pyhc364b38_0
# Linking aiosignal-1.4.0-pyhd8ed1ab_0
# Linking urllib3-2.7.0-pyhd8ed1ab_0
# Linking awkward-2.13.0-pyhcf101f3_0
# Linking ipython-9.17.1-pyh53cf698_0
# Linking jupyter_client-8.10.0-pyhcf101f3_0
# Linking pip-26.2.1-pyh8b19718_0
# Linking requests-2.34.2-pyhcf101f3_0
# Linking uproot-5.7.6-pyhc364b38_0
# Linking ipykernel-6.31.0-pyha191276_0
# Linking atlasopenmagic-1.10.1-pyhc364b38_0
# Linking fonttools-4.65.0-py311h92159aa_0
# Linking yarl-1.24.5-py311h3778330_0
# Linking pandas-2.3.3-py311hed34c8f_2
# Linking matplotlib-base-3.11.1-py311he401cf6_2
# Linking aiohttp-3.14.3-py311h55b9665_0
#
# Transaction finished
#
# Collect information..
# Cleaning index cache..
# Cleaning lock files..
#   Package file                                           Size
# ───────────────────────────────────────────────────────────────
#   /opt/conda/pkgs
# ───────────────────────────────────────────────────────────────
#
#   _openmp_mutex-4.5-20_gnu.conda                         29kB
#   _x86_64-microarch-level-3-3_x86_64_v3.conda            10kB
#   aiohappyeyeballs-2.7.1-pyhd8ed1ab_0.conda              25kB
#   aiohttp-3.14.3-py311h55b9665_0.conda                    1MB
#   aiosignal-1.4.0-pyhd8ed1ab_0.conda                     14kB
#   asttokens-3.0.2-pyhd8ed1ab_0.conda                     35kB
#   atlasopenmagic-1.10.1-pyhc364b38_0.conda               47kB
#   attrs-26.1.0-pyhcf101f3_0.conda                        65kB
#   awkward-2.13.0-pyhcf101f3_0.conda                     542kB
#   awkward-cpp-56-py311h2bf5405_2.conda                  674kB
#   backports.zstd-1.7.0-py311h6f959d0_1.conda            248kB
#   brotli-1.2.0-h505cf86_4.conda                          21kB
#   brotli-bin-1.2.0-h9908984_4.conda                      22kB
#   brotli-python-1.2.0-py311heb3be6f_4.conda             367kB
#   bzip2-1.0.8-hda65f42_10.conda                         258kB
#   ca-certificates-2026.7.22-hbd8a1cb_0.conda            132kB
#   cairo-1.18.4-h3c89d7e_3.conda                         991kB
#   certifi-2026.7.22-pyhd8ed1ab_0.conda                  137kB
#   charset-normalizer-3.5.1-pyhd8ed1ab_0.conda            64kB
#   comm-0.2.3-pyhe01879c_0.conda                          15kB
#   contourpy-1.3.3-py311h724c32c_4.conda                 321kB
#   cramjam-2.11.0-py311hc665cac_2.conda                    2MB
#   cycler-0.12.1-pyhcf101f3_2.conda                       15kB
#   debugpy-1.8.21-py311hdfc3925_2.conda                    3MB
#   executing-2.2.1-pyhd8ed1ab_0.conda                     31kB
#   font-ttf-dejavu-sans-mono-2.37-hab24e00_0.tar.bz2     397kB
#   font-ttf-inconsolata-3.000-h77eed37_0.tar.bz2          97kB
#   font-ttf-source-code-pro-2.038-h77eed37_0.tar.bz2     701kB
#   font-ttf-ubuntu-0.83-h77eed37_3.conda                   2MB
#   fontconfig-2.18.3-h4db4eae_1.conda                    296kB
#   fonts-conda-ecosystem-1-0.tar.bz2                       4kB
#   fonts-conda-forge-1-hc364b38_1.conda                    4kB
#   fonttools-4.65.0-py311h92159aa_0.conda                  3MB
#   freetype-2.14.3-ha770c72_2.conda                      175kB
#   fribidi-1.0.16-h7cc23a3_2.conda                        62kB
#   frozenlist-1.8.0-py311h52bc045_0.conda                 54kB
#   fsspec-2026.7.0-pyhd8ed1ab_0.conda                    152kB
#   graphite2-1.3.15-h54a6638_1.conda                     103kB
#   h2-4.4.1-pyhcf101f3_0.conda                           101kB
#   hpack-4.2.0-pyhd8ed1ab_0.conda                         33kB
#   hyperframe-6.1.0-pyhd8ed1ab_0.conda                    17kB
#   icu-78.3-py310h44b86e0_2.conda                         14MB
#   idna-3.19-pyhcf101f3_0.conda                          177kB
#   importlib-metadata-9.0.1-pyhcf101f3_0.conda            35kB
#   ipykernel-6.31.0-pyha191276_0.conda                   130kB
#   ipython-9.17.1-pyh53cf698_0.conda                     731kB
#   ipython_pygments_lexers-1.1.1-pyhd8ed1ab_0.conda       14kB
#   jedi-0.20.0-pyhcf101f3_0.conda                          3MB
#   jupyter_client-8.10.0-pyhcf101f3_0.conda              119kB
#   jupyter_core-5.9.1-pyhc90fa1f_0.conda                  66kB
#   keyutils-1.6.3-h7cc23a3_1.conda                       135kB
#   kiwisolver-1.5.1-py311h4c6fd42_1.conda                 77kB
#   krb5-1.22.2-hbc21106_2.conda                            1MB
#   lcms2-2.19.1-h9073bf1_3.conda                         254kB
#   ld_impl_linux-64-2.46.1-default_hbd61a6d_102.conda    745kB
#   lerc-4.2.0-hdb68285_0.conda                           271kB
#   libblas-3.11.0-11_h4a7cf45_openblas.conda              18kB
#   libbrotlicommon-1.2.0-h39a168f_4.conda                 81kB
#   libbrotlidec-1.2.0-ha411449_4.conda                    35kB
#   libbrotlienc-1.2.0-h018ffa1_4.conda                   298kB
#   libcblas-3.11.0-11_h0358290_openblas.conda             18kB
#   libdeflate-1.25-hd45a770_1.conda                       74kB
#   libedit-3.1.20250104-pl5321h373387f_1.conda           135kB
#   libexpat-2.8.1-hecca717_1.conda                        78kB
#   libffi-3.7.0-h81df57d_1.conda                          68kB
#   libfreetype-2.14.3-ha770c72_2.conda                     8kB
#   libfreetype6-2.14.3-h5e6c136_2.conda                  388kB
#   libgcc-16.2.0-ha9f2e26_5.conda                          1MB
#   libgcc-ng-16.2.0-h69a702a_5.conda                      29kB
#   libgfortran-16.2.0-h69a702a_5.conda                    29kB
#   libgfortran5-16.2.0-h6b99dfc_5.conda                    3MB
#   libglib-2.90.0-h569388d_0.conda                         5MB
#   libgomp-16.2.0-he0feb66_5.conda                       642kB
#   libharfbuzz-14.4.0-h23af247_1.conda                     1MB
#   libiconv-1.18-h0cb94f2_3.conda                        789kB
#   libjpeg-turbo-3.2.0-hb03c661_1.conda                  650kB
#   liblapack-3.11.0-11_h47877c9_openblas.conda            18kB
#   liblzma-5.8.3-hb03c661_1.conda                        113kB
#   libnsl-2.0.1-hb9d3cd8_1.conda                          34kB
#   libopenblas-0.3.34-pthreads_hf13c14d_2.conda            7MB
#   libpng-1.6.58-h922cc85_1.conda                        317kB
#   libpython-3.11.16-h0c77377_2_cpython.conda              8MB
#   libraqm-0.11.0-h6406941_0.conda                        34kB
#   libsodium-1.0.22-hebe6cf0_3.conda                     271kB
#   libsqlite-3.53.4-h13e7031_1.conda                     974kB
#   libstdcxx-16.2.0-h934c35e_5.conda                       7MB
#   libstdcxx-ng-16.2.0-hdf11a46_5.conda                   29kB
#   libtiff-4.7.2-hcc2c06a_1.conda                        460kB
#   libuuid-2.42.3-hcfc3c73_0.conda                        40kB
#   libwebp-base-1.6.0-hd42ef1d_1.conda                   428kB
#   libxcb-1.17.0-hb83e432_2.conda                        395kB
#   libxcrypt-4.4.38-h280c20c_0.conda                     102kB
#   libzlib-1.3.2-h25fd6f3_3.conda                         64kB
#   matplotlib-base-3.11.1-py311he401cf6_2.conda            9MB
#   matplotlib-inline-0.2.2-pyhd8ed1ab_0.conda             16kB
#   multidict-6.7.1-py311h3778330_0.conda                 101kB
#   munkres-1.1.4-pyhd8ed1ab_1.conda                       16kB
#   ncurses-6.6-hdb14827_1.conda                          911kB
#   nest-asyncio-1.6.0-pyhd8ed1ab_1.conda                  12kB
#   numpy-2.4.6-py311h2e04523_0.conda                       9MB
#   openjpeg-2.5.4-heb1ab33_2.conda                       391kB
#   openssl-3.6.4-h781a0a9_0.conda                          3MB
#   packaging-26.3-pyhc364b38_0.conda                     116kB
#   pandas-2.3.3-py311hed34c8f_2.conda                     15MB
#   parso-0.8.7-pyhcf101f3_0.conda                         82kB
#   pcre2-10.47-h8b3dc9c_1.conda                            1MB
#   pexpect-4.9.0-pyhd8ed1ab_1.conda                       54kB
#   pillow-12.3.0-py311hf303fd3_4.conda                     1MB
#   pip-26.2.1-pyh8b19718_0.conda                           1MB
#   pixman-0.46.4-h54a6638_3.conda                        377kB
#   platformdirs-4.11.8-pyh5ded981_0.conda                 28kB
#   prompt-toolkit-3.0.53-pyha770c72_0.conda              276kB
#   propcache-0.5.2-py311h3778330_0.conda                  51kB
#   psutil-7.2.2-py311h194be0f_2.conda                    232kB
#   pthread-stubs-0.4-h7cc23a3_1004.conda                  10kB
#   ptyprocess-0.7.0-pyhd8ed1ab_1.conda                    19kB
#   pure_eval-0.2.4-pyhd8ed1ab_0.conda                     18kB
#   pygments-2.21.0-pyhcf101f3_0.conda                    959kB
#   pyparsing-3.3.2-pyhcf101f3_0.conda                    111kB
#   pysocks-1.7.1-pyha55dd90_7.conda                       21kB
#   python-3.11.16-h5f976f7_2_cpython.conda                23MB
#   python-dateutil-2.9.0.post0-pyhe01879c_2.conda        233kB
#   python-tzdata-2026.3-pyhd8ed1ab_0.conda               147kB
#   python-xxhash-3.7.0-py311h6cc6551_1.conda              25kB
#   python_abi-3.11-9_cp311.conda                           7kB
#   pytz-2026.3.post1-pyhcf101f3_0.conda                  201kB
#   pyyaml-6.0.3-py311h3778330_1.conda                    206kB
#   pyzmq-27.2.0-py311hcbe55da_1.conda                    396kB
#   qhull-2020.2-h434a139_5.conda                         553kB
#   readline-8.3-hd6e31c0_1.conda                         349kB
#   requests-2.34.2-pyhcf101f3_0.conda                     69kB
#   setuptools-84.0.0-pyh332efcf_0.conda                  524kB
#   six-1.17.0-pyhe01879c_1.conda                          18kB
#   stack_data-0.6.3-pyhd8ed1ab_1.conda                    27kB
#   tk-8.6.13-noxft_h1df4ec4_4.conda                        4MB
#   tornado-6.5.8-py311h0d48ccd_2.conda                   889kB
#   tqdm-4.70.1-pyhfa0c392_0.conda                         96kB
#   traitlets-5.16.1-pyhcf101f3_0.conda                   117kB
#   typing_extensions-4.16.0-pyhcf101f3_0.conda            53kB
#   tzdata-2026c-h151e31d_0.conda                         119kB
#   unicodedata2-17.0.1-py311h0d48ccd_1.conda             413kB
#   uproot-5.7.6-pyhc364b38_0.conda                       287kB
#   urllib3-2.7.0-pyhd8ed1ab_0.conda                      104kB
#   vector-1.8.1-pyhc364b38_0.conda                        98kB
#   wcwidth-0.8.3-pyhcf101f3_0.conda                      146kB
#   wheel-0.48.0-pyhd8ed1ab_0.conda                        35kB
#   xorg-libice-1.1.2-h280c20c_0.conda                     63kB
#   xorg-libsm-1.2.6-h0d788c3_1.conda                      31kB
#   xorg-libx11-1.8.13-he1eb515_1.conda                   840kB
#   xorg-libxau-1.0.12-h7cc23a3_2.conda                    19kB
#   xorg-libxdmcp-1.1.5-hb03c661_2.conda                   21kB
#   xorg-libxext-1.3.7-h7cc23a3_1.conda                    53kB
#   xorg-libxrender-0.9.12-hb03c661_1.conda                35kB
#   xxhash-0.8.3-hec8ed23_1.conda                         109kB
#   yaml-0.2.5-hebe6cf0_3.conda                            85kB
#   yarl-1.24.5-py311h3778330_0.conda                     173kB
#   zeromq-4.3.5-h901266b_12.conda                        322kB
#   zipp-4.1.0-pyhcf101f3_0.conda                          24kB
#   zlib-ng-2.3.3-hce19668_1.conda                        124kB
#   zstd-1.5.7-hb78ec9c_7.conda                           601kB
#
#   /home/mambauser/.mamba/pkgs
# ───────────────────────────────────────────────────────────────
#
#
#
# ───────────────────────────────────────────────────────────────
#
#   Total size:                                           154MB
# Cleaning tarballs..
# Cleaning packages..
# --> 11977b254fb6
# STEP 5/6: WORKDIR /tmp
# --> 426c5cd8266e
# STEP 6/6: CMD ["python"]
# COMMIT localhost/atlas-notebook-find-z:v1
# --> 6ef904cb580f
# Successfully tagged localhost/atlas-notebook-find-z:v1
# 6ef904cb580fa2974b74e1a86ebaf244a1762167cf0ed0c81a55d93c582bcd48

# %% [markdown]
# - **`--file Containerfile`:** the build recipe.
# - **`--tag`:** the image name used throughout this notebook.
# - **`.`:** the build context—the current directory.
#
# **Expected result:** the build finishes and tags the image.
#
# <details>
# <summary>Build troubleshooting</summary>
#
# If a build fails, inspect the first failing instruction. For `pasta` network-helper failures, see [NERSC’s network options](https://docs.nersc.gov/development/containers/podman-hpc/overview/#network-options-with-the-container); `--network=slirp4netns` is a possible fallback after `build` or `run`.
#
# After changing the environment, rebuild and migrate the image, restart the container kernel, and rerun the checks.
#
# </details>

# %% [markdown]
# ### Check the environment
#
# First, list just the tutorial image:

# %%
# %%bash
# podman-hpc images --filter reference=localhost/atlas-notebook-find-z:v1
# Out:
# REPOSITORY                       TAG         IMAGE ID      CREATED         SIZE
# localhost/atlas-notebook-find-z  v1          6ef904cb580f  48 seconds ago  921 MB

# %% [markdown]
# The listing should include the tutorial image. Now start a temporary container and check that the required packages import.
#
# `--rm` removes the container when it exits; the image remains.

# %%
# %%bash
# podman-hpc run --rm localhost/atlas-notebook-find-z:v1 python -c '
# import atlasopenmagic, awkward, ipykernel, matplotlib, numpy, pandas, uproot, vector
# import requests, aiohttp
# print("Analysis imports OK")
# '
# Out:
# Analysis imports OK

# %% [markdown]
# **Expected result:** `Analysis imports OK`, with no import errors. Section 5 will test data access by running the analysis.

# %% [markdown]
# ### Make the image available to Jupyter
#
# On the build node, use `podman-hpc migrate` to make the image available on shared storage for other nodes. See [NERSC’s image guidance](https://docs.nersc.gov/development/containers/podman-hpc/overview/#building-images).

# %%
# %%bash
# podman-hpc migrate localhost/atlas-notebook-find-z:v1
# podman-hpc images --filter reference=localhost/atlas-notebook-find-z:v1
# Out:
# REPOSITORY                       TAG         IMAGE ID      CREATED             SIZE        R/O
# localhost/atlas-notebook-find-z  v1          6ef904cb580f  About a minute ago  921 MB      false
# localhost/atlas-notebook-find-z  v1          6ef904cb580f  About a minute ago  921 MB      true

# %% [markdown]
# ### ⚑ Checkpoint: Software environment ready
#
# > The image builds successfully, and the dependency checks pass.
#
# Confirm that the image listing contains a migrated copy (`R/O` is `true`) before continuing to Section 4.
#
# <details>
# <summary>Further reading</summary>
#
# - [Podman-HPC beginner tutorial](https://docs.nersc.gov/development/containers/podman-hpc/podman-beginner-tutorial/).
# - [Using Podman-HPC at NERSC](https://docs.nersc.gov/development/containers/podman-hpc/overview/).
# - [Dockerfile reference](https://docs.docker.com/reference/dockerfile/).
#
# </details>

# %% [markdown]
# ## 4 - Containers on NERSC JupyterHub

# %% [markdown]
# ### Keep the notebook; change the kernel
#
# The **kernel** executes your notebook’s code. A **kernelspec** (`kernel.json`) tells Jupyter which command starts it.
#
# We’ll generate the kernelspec with `ipykernel`, then prepend the container launch command using `jq`. See [NERSC’s container-kernel guide](https://docs.nersc.gov/services/jupyter/how-to-guides/#how-to-use-a-container-to-run-a-jupyter-kernel).
#
# **Where to run setup:** use **NERSC Python**, not the ATLAS container kernel, or a **host terminal** with `%%bash` omitted. You need `podman-hpc`, `jq`, the migrated image, and a checkout under your home directory.
#
# **Alternative:** [Shifter-backed kernels](https://docs.nersc.gov/services/jupyter/how-to-guides/#shifter) use the same principle, with different image preparation and launch options.

# %% [markdown]
# ### 1. Include ipykernel in the container
#
# Our environment already includes `ipykernel`, which lets the container’s Python communicate with Jupyter.

# %% [markdown]
# ### 2. Generate and configure the kernelspec
#
# The cell below uses the container’s Python to generate `kernel.json`, then uses `jq` to prepend the container launch command to `argv`. The generated Python arguments and `{connection_file}` placeholder are preserved.
#
# `--prefix "$HOME/.local"` installs the kernelspec in your mounted home directory. Rerunning the whole cell replaces this tutorial’s kernelspec with a fresh one before adding the wrapper.

# %%
# %%bash
# set -euo pipefail
#
# spec="$HOME/.local/share/jupyter/kernels/atlas-notebook-find-z/kernel.json"
# image="localhost/atlas-notebook-find-z:v1"
#
# # Generate a fresh kernelspec.
# podman-hpc run --rm --jupyter \
#     --userns=keep-id:uid=57439,gid=57439 \
#     --env HOME \
#     "$image" \
#     /opt/conda/bin/python -m ipykernel install \
#     --prefix "$HOME/.local" \
#     --name atlas-notebook-find-z \
#     --display-name "ATLAS Find Z (container)"
#
# # Launch the generated Python command inside the container.
# jq --arg image "$image" '
#     .argv = [
#         "podman-hpc", "run", "--rm", "--jupyter",
#         "--userns=keep-id:uid=57439,gid=57439",
#         "--env", "HOME",
#         $image
#     ] + .argv
# ' "$spec" > "$spec.tmp"
# mv "$spec.tmp" "$spec"
#
# jq . "$spec"
# Out:
# Installed kernelspec atlas-notebook-find-z in /global/homes/a/asnaylor/.local/share/jupyter/kernels/atlas-notebook-find-z
# {
#   "argv": [
#     "podman-hpc",
#     "run",
#     "--rm",
#     "--jupyter",
#     "--userns=keep-id:uid=57439,gid=57439",
#     "--env",
#     "HOME",
#     "localhost/atlas-notebook-find-z:v1",
#     "/opt/conda/bin/python",
#     "-Xfrozen_modules=off",
#     "-m",
#     "ipykernel_launcher",
#     "-f",
#     "{connection_file}"
#   ],
#   "display_name": "ATLAS Find Z (container)",
#   "language": "python",
#   "metadata": {
#     "debugger": true
#   }
# }

# %% [markdown]
# Jupyter will now launch the container before starting Python. We write the edited JSON to a temporary file, then replace `kernel.json`, because `jq` cannot read and overwrite the same file directly.
#
# <details>
# <summary>What do the container options do?</summary>
#
# - `--jupyter` mounts home and `/tmp`; `--env HOME` passes your home path.
# - `--userns=keep-id:uid=57439,gid=57439` maps your account to this image’s non-root user so it can access your files. It does not change host file ownership.
#
# The numeric IDs belong to this image, not your NERSC account. See [Podman’s user mapping documentation](https://docs.podman.io/en/latest/markdown/podman-run.1.html#userns-mode).
#
# </details>

# %% [markdown]
# ### 3. Select the container kernel
#
# After creating or editing the kernelspec, **save the notebook and reload the JupyterLab browser tab**. Then choose **Kernel → Change Kernel → ATLAS Find Z (container)**. If it is still missing, restart your server using the steps below.
#
# <details>
# <summary>If the kernel does not appear: restart your Jupyter server</summary>
#
# 1. Save all open notebooks; stopping the server ends its kernels and clears in-memory variables.
# 2. Select **File → Hub Control Panel**.
# 3. Once the control panel opens, close the old JupyterLab tab.
# 4. Stop your running server, wait for it to stop, then start a new server with the resources you need.
# 5. Reopen this notebook and select **ATLAS Find Z (container)**.
#
# This restarts your server, not the shared JupyterHub service. [NERSC’s restart guidance](https://docs.nersc.gov/services/jupyter/how-to-guides/#how-to-use-a-conda-environment-as-a-python-kernel) also distinguishes this from restarting an existing kernel after changing its launch settings.
#
# </details>
#
# Switching kernels starts a fresh Python session. Run the verification cells below, not the setup cell again.
#
# ### 4. Verify the environment
#
# Check the Python interpreter and select the repository directory. The image starts in `/tmp`.
#
# > **Before running the next cell:** set `repo` to the location where you cloned this repository. The example assumes `~/notebook-laptop-to-nersc`. If you cloned into another directory under your home directory, update the path to match.

# %%
import os
import sys
from pathlib import Path

print("Python:", sys.executable)
assert sys.executable == "/opt/conda/bin/python"

# EDIT this path if you cloned the repository elsewhere under your home directory.
repo = Path.home() / "projects/notebook-laptop-to-nersc"
assert (repo / "utils/find_the_z.py").is_file(), f"Check the repository path: {repo}"
os.chdir(repo)
print("Analysis directory:", Path.cwd())
# Out:
# Python: /opt/conda/bin/python
# Analysis directory: /global/homes/a/asnaylor/projects/notebook-laptop-to-nersc

# %%
import atlasopenmagic, awkward, ipykernel, matplotlib, numpy, pandas, uproot, vector
import requests, aiohttp
from utils.find_the_z import process_data, plot_result

print("Analysis imports OK")
# Out:
# Analysis imports OK

# %% [markdown]
# ### ⚑ Checkpoint: Jupyter connection ready
#
# > The selected kernel runs Python inside the container and imports the analysis packages.
#
# <details>
# <summary>Troubleshooting and further reading</summary>
#
# - **Image unavailable:** check the image name and migration under your account.
# - **Permission denied:** check the user mapping and mounted paths; do not change ownership of your home directory.
# - **Kernel disconnected:** inspect the kernelspec and Jupyter server error output.
# - **Missing dependencies:** update the environment, rebuild and migrate the image, then restart the kernel.
# - **Local module missing:** check the repository path and current directory.
#
# References: [NERSC kernels](https://docs.nersc.gov/services/jupyter/how-to-guides/#how-to-use-a-container-to-run-a-jupyter-kernel), [Jupyter kernelspecs](https://jupyter-client.readthedocs.io/en/stable/kernels.html#kernel-specs), and the [jq manual](https://jqlang.org/manual/).
#
# </details>

# %% [markdown]
# ## 5 - Running the Analysis

# %% [markdown]
# Keep **ATLAS Find Z (container)** selected.
#
# ### 1. Access the example data
#
# Select the tutorial’s data release and `2muons` skim (events with at least two muons, each with transverse momentum of at least 10 GeV). We’ll process one file.

# %%
import atlasopenmagic as atom

# Select the ATLAS Open Data release used for this tutorial.
atom.set_release('2025e-13tev-beta')
skim = '2muons'

files_list = atom.get_urls('data', skim, protocol='https', cache=True)
print(f"Available files: {len(files_list)}")
# Out:
# Fetching metadata for release: 2025e-13tev-beta...
# Fetching datasets: 100%|██████████| 374/374 [00:00<00:00, 533.27datasets/s]
# ✓ Successfully cached 374 datasets.
# Active release: 2025e-13tev-beta. (Datasets path: REMOTE)
# Available files: 16

# %% [markdown]
# <details>
# <summary>Optional: check a single event</summary>
#
# After the data-access cell, run this in the container kernel to check the required ROOT branches before processing.
#
# ```python
# import uproot
#
# assert len(files_list) > 0, "No data files were returned; check the data-access step."
# with uproot.open(f"{files_list[0]}:analysis") as tree:
#     sample = tree.arrays(
#         ["lep_pt", "lep_eta", "lep_phi", "lep_e"],
#         entry_start=0,
#         entry_stop=1,
#         library="ak",
#     )
#
# assert len(sample) == 1, "The selected file contains no events."
# print("Data-access check passed: read one event and all four required branches.")
# ```
#
# [Uproot reading guide](https://uproot.readthedocs.io/en/stable/basic.html).
#
# </details>

# %% [markdown]
# ### 2. Run the analysis
#
# The [analysis functions](utils/find_the_z.py) read the muon measurements and calculate the pair’s invariant mass. For this demonstration, use the first file; the function processes half its events.

# %%
from utils.find_the_z import process_data, plot_result

assert len(files_list) > 0, "No data files were returned; check the data-access step."
demo_files = files_list[:1]
mass_list = process_data(demo_files)
# Out:
# Working on file simplecache::https://opendata.cern.ch/eos/opendata/atlas/rucio/opendata/ODEO_FEB2025_v0_2muons_data15_periodD.2muons.root (0/1)

# %% [markdown]
# ### 3. Plot and interpret
#
# Look for a peak near **91 GeV**, the Z boson mass. The vertical axis shows events per mass bin on a logarithmic scale.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(7, 4))
plot_result(mass_list)
plt.show()

# %% [markdown]
# ### ⚑ Checkpoint: Analysis verified
#
# > Data access works, and the plot shows a peak near the Z boson mass.

# %% [markdown]
# ## 6 - Summary and Further Exploration

# %% [markdown]
# ### What we accomplished
#
# We ran the ATLAS analysis through a container-backed Jupyter kernel. You’ve learned to:
#
# - **Build a container image** containing your analysis software.
# - **Configure Jupyter to use it**, while retaining your notebook interface.

# %% [markdown]
# ### Where to go next
#
# **Batch jobs:** reuse the environment from a Slurm job, launching an analysis script instead of a Jupyter kernel.
#
# <details>
# <summary>Try it later</summary>
#
# Write a small driver that calls `process_data` and `plot_result`, saves the figure, and runs inside the container from a batch script. This suits longer or repeated analyses without interactive input.
#
# </details>

# %% [markdown]
# **GPUs:** extend the workflow to a GPU-enabled notebook.
#
# <details>
# <summary>Try it later</summary>
#
# 1. Build an image with a compatible GPU-enabled library such as CuPy or PyTorch, plus `ipykernel`.
# 2. Start a NERSC Jupyter session with GPU resources.
# 3. Add `--gpu` alongside `--jupyter` in the kernel launch command.
# 4. Check GPU detection and run a small calculation.
#
# See [NERSC’s GPU container guidance](https://docs.nersc.gov/development/containers/podman-hpc/overview/#using-nvidia-gpus-in-podman-hpc).
#
# </details>

# %% [markdown]
# **Sharing:** publish the image so collaborators can reuse the environment.
#
# <details>
# <summary>Try it later</summary>
#
# Push a versioned image to NERSC’s private, project-based registry. Collaborators with access can pull it instead of rebuilding. Follow the [NERSC registry guide](https://docs.nersc.gov/development/containers/registry/); you may need to request access.
#
# </details>

# %% [markdown]
# **Automation:** build, test, and publish images with GitHub Actions.
#
# <details>
# <summary>Try it later</summary>
#
# Create a workflow that builds the image, runs checks you define, and publishes to GitHub Container Registry (`ghcr.io`). Tag builds with release or commit identifiers, then pull the image at NERSC.
#
# [GitHub’s publishing guide](https://docs.github.com/en/actions/tutorials/publish-packages/publish-docker-images) covers build and publication; add your own test steps.
#
# </details>

# %% [markdown]
# Bring your own scientific notebook next: **package its environment, connect it to Jupyter, and continue your science at NERSC.**
#
# <details>
# <summary>Useful resources</summary>
#
# - [Podman-HPC tutorial](https://docs.nersc.gov/development/containers/podman-hpc/podman-beginner-tutorial/).
# - [Container-backed Jupyter kernels](https://docs.nersc.gov/services/jupyter/how-to-guides/#how-to-use-a-container-to-run-a-jupyter-kernel).
# - [Micromamba container guide](https://micromamba-docker.readthedocs.io/en/latest/quick_start.html).
#
# </details>
